# %% [markdown]
# # Деревья принятия решений

# %% [markdown]
# # 1.1 Основы ООП в Python

# %% [markdown]
# 1.2.1 Пример
#
# Необходимо разработать виртуальную модель процесса обучения. В
# программе должны быть объекты-ученики, учитель, кладезь знаний

# %%
class Data:
    def __init__(self, *info):
        self.info = list(info)
    def __getitem__(self, i):
        return self.info[i]

class Teacher:
    def teach(self, info, *pupipl):
        for i in pupipl:
            i.take(info)


class Pupil:
    def __init__(self):
        self.knowledge = []
    def take(self, info):
        self.knowledge.append(info)


lesson = Data('class', 'object', 'inheritance', 'polimorphism', 'encapsulation')

marIvanna = Teacher()
vasy = Pupil()
pety = Pupil()

marIvanna.teach(lesson[2], vasy, pety)
marIvanna.teach(lesson[0], pety)

print(vasy.knowledge)
print(pety.knowledge)
# Out:
# ['inheritance']
# ['inheritance', 'class']

# %% [markdown]
# 1.2.2 Пример
#
# Напишите программу по следующему описанию. Есть класс "Воин". От
# него создаются два экземпляра-юнита. Каждому устанавливается здоровье
# в 100 очков. В случайном порядке они бьют друг друга. Тот, кто бьет,
# здоровья не теряет. У того, кого бьют, оно уменьшается на 20 очков от
# одного удара. После каждого удара надо выводить сообщение, какой юнит
# атаковал, и сколько у противника осталось здоровья. Как только у кого-то
# заканчивается ресурс здоровья, программа завершается сообщением о том,
# кто одержал победу

# %%
import random

class Warrior:
    def __init__(self, health):
        self.health = health

    def hit(self, target, target1):
        if target.health > 0:
            target.health -= 20
        if target1 == warrior1:
            target1 = 'Warrior1'
        if target1 == warrior2:
            target1 = 'Warrior2'
        print(target1, 'has attacked')
        print(target.health, 'left')
        if target.health == 0:
            print(target1, 'has won')


warrior1 = Warrior(100)
warrior2 = Warrior(100)
q = int(input("Enter 1 to attack. Enter 2 to stop program:"))

while q != 2:
    if q == 1:
        j = random.randint(1,3)
        if j % 2 == 0:
            warrior1.hit(warrior2, warrior1)
            q = int(input("Enter 1 to let some warrior attack:"))
        else:
            warrior2.hit(warrior1, warrior2)
            q = int(input("Enter 1 to let some warrior attack:"))
    else:
        print("Wrong input")
        break
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [37], line 22
#      20 warrior1 = Warrior(100)
#      21 warrior2 = Warrior(100)
# ---> 22 q = int(input("Enter 1 to attack. Enter 2 to stop program:"))
#      24 while q != 2:
#      25     if q == 1:
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# 1.2.3 Пример
#
# Создайте класс по работе с дробями. В классе должна быть
# реализована следующая функциональность:
# − сложение дробей;
# − вычитание дробей;
# − умножение дробей;
# − деление дробей.

# %%
class Rational:

    @staticmethod
    def gcd(a,b):
        while (b != 0):
            (a, b) = (b, a%b)
        return a

    @staticmethod
    def sgn(x):
        if x>0:
            return 1
        elif x<0:
            return -1
        else:
            return 0

    def __init__(self, n, d):
        if n==0:
            self.num=0
            self.den=1
        else:
            z = self.sgn(n)*self.sgn(d)
            n = abs(n)
            d = abs(d)
            k = self.gcd(n, d)
            self.num = z*n//k
            self.den = d//k

    def __str__(self):
        if self.num == 0:
            return "0"
        else:
            return str(self.num)+"/"+str(self.den)

    def __add__(self,o):
        n1=self.num
        d1=self.den
        if type(o)==int:
            n2 = o
            d2=1
        else:
            n2=o.num
            d2=o.den
        n=n1*d2+n2*d1
        d=d1*d2
        return Rational(n,d)

    def __radd__(self,o):
        n1=self.num
        d1=self.den
        if type(o)==int:
            n2 = o
            d2=1
        else:
            n2=o.num
            d2=o.den
        n=n1*d2+n2*d1
        d=d1*d2
        return Rational(n,d)

    def __sub__(self,o):
        n1=self.num
        d1=self.den
        n2=o.num
        d2=o.den
        n=n1*d2-n2*d1
        d=d1*d2
        return Rational(n,d)

    def __mul__(self, o):
        n1=self.num
        d1=self.den
        n2=o.num
        d2=o.den
        n=n1*n2
        d=d1*d2
        return Rational(n,d)

    def __floordiv__(self,o):
        n1=self.num
        d1=self.den
        n2=o.num
        d2=o.den
        n=n1*n2
        d=d1*d2
        return Rational(n,d)

d1=Rational(1,2)
d2=Rational(1,3)
d3=d1+d2
print(d3)
d4=d1-d2
print(d4)
d5=d1*d2
print(d5)
d6=d1*d2
print(d6)
d7=d1//d2
print(d7)
d8=6+d1
print(d8)
# Out:
# 5/6
# 1/6
# 1/6
# 1/6
# 1/6
# 13/2

# %% [markdown]
# 1.2.3 Задание № 1:
# Создайте класс по работе с тригонометрическими функциями. В классе
# должны быть реализованы функции вычисления:
# − косинуса;
# − синуса;
# − тангенса;
# − арксинуса;
# − арккосинуса;
# − арктангенса;
# − перевода из градусов в радианы.

# %%
import math

class Trig:
    def __init__(self):
        pass

    def cos(self, angle):
        return math.cos(angle)

    def sin(self, angle):
        return math.sin(angle)

    def tan(self, angle):
        return math.tan(angle)

    def acos(self, value):
        return math.acos(value)

    def asin(self, value):
        return math.asin(value)

    def tan(self, value):
        return math.atan(value)

    def degrees(self, degrees):
        return math.radians(degrees)

res = Trig()
res.sin(30)
# Out:
# -0.9880316240928618

# %% [markdown]
# # 1.2. Реализация деревьев в Python

# %% [markdown]
# 1.2.1 Пример
#
# Определите класс бинарного дерева и задайте его объекты с отдельным
# атрибутом для каждого из потомков.

# %%
class Tree:
    def __init__(self, left, right):
        self.left = left
        self.right = right

t = Tree(Tree("a", "b"), Tree("c", "d"))
print(t.right)
print(t.left)
print(t.right.left)
print(t.right.right)

# %% [markdown]
# 1.2.2 Пример
#
# Для обозначения отсутствующих потомков можно использовать None
# (в случае если у узла только один потомок). Само собой, можно
# комбинировать разные методы (например, использовать списки или
# множества потомков для каждого узла).
# Распространенный способ реализации деревьев, особенно на языках,
# не имеющих встроенной поддержки списков, это так называемое
# представление «первый потомок, следующий брат». В нем каждый узел
# имеет два «указателя» или атрибута, указывающих на другие узлы, как в
# бинарном дереве. Однако, первый из этих атрибутов ссылается на первого
# потомка узла, а второй — на его следующего брата (т.е. узел, имеющий
# того же родителя, но находящийся правее, — прим. перев). Иными
# словами, каждый узел дерева имеет указатель на связанный список его
# потомков, а каждый из этих потомков ссылается на свой собственный
# аналогичный список. Таким образом, небольшая модификация бинарного
# дерева даст нам многопутевое дерево, показанное в листинге ниже

# %%
class Tree:
    def __init__(self, kids, next=None):
        self.kids = self.val = kids
        self.next = next

t = Tree(Tree("a", Tree("b", Tree("c", Tree("d")))))
print(t.kids.next.next.val)

# %% [markdown]
# 1.2.1 Задание № 1:
#
# Представьте дерево показанное на рисунке с использованием списка из
# списков. Выведите на печать корень дерева, а также его левое и правое
# поддеревья.
#     a
#  b    c
# d e   f

# %%
Tree = ['a', ['b', ['d','e'] ], ['c', ['f']] ]
print(Tree)
print('left subtree = ', Tree[1])
print('root = ', Tree[0])
print('right subtree = ', Tree[2])
# Out:
# ['a', ['b', ['d', 'e']], ['c', ['f']]]
# left subtree =  ['b', ['d', 'e']]
# root =  a
# right subtree =  ['c', ['f']]

# %% [markdown]
# 1.2.1 Задание № 2:
#
# Дан класс, описывающий бинарное дерево.
# class Tree:
#     def __init__(self, data):
#         self.left = None
#         self.right = None
#         self.data = data
#     def PrintTree(self):
#         print(self.data)
#
# Реализуйте в классе функцию для вставки нового элемента в дерево по
# следующим правилам:
# • Левое поддерево узла содержит только узлы со значениями меньше,
# чем значение в узле.
# • Правое поддерево узла содержит только узлы со значениями меньше,
# чем значение в узле.
# • Каждое из левого и правого поддеревьев также должно быть
# бинарным деревом поиска.
# • Не должно быть повторяющихся узлов.
# Метод вставки сравнивает значение узла с родительским узлом и решает
# куда доваить элемент (в левое или правое поддерево). Перепишите, метод
# PrintTree для печати полной версии дерева.

# %%
class Tree:
    def __init__(self, data):
        self.left = None
        self.right = None
        self.data = data

    def insert(self, value):
        if value == self.data:
            return False
        elif value < self.data:
            if self.left:
                return self.left.insert(value)
            else:
                self.left = Tree(value)
                return True
        else:
            if self.right:
                return self.right.insert(value)
            else:
                self.right = Tree(value)
                return True

    def PrintTree(self):
        if self.left:
            self.left.PrintTree()
        print(self.data)
        if self.right:
            self.right.PrintTree()

MyTree = Tree(6)
MyTree.insert(4)
MyTree.insert(3)
MyTree.insert(5)
MyTree.PrintTree()
# Out:
# 3
# 4
# 5
# 6

# %% [markdown]
# # 1.3 Деревья решений

# %% [markdown]
# 1.3.1 Пример
#
# Построим дерево решений для задачи классификации, для этого, построим
# границу решения для каждого класса. В качестве данных будем
# использовать уже знакомый нам и встроенный в библиотеку sklearn набор
# данных ирисов Фишера. Импортируем библиотеки, набор данных и
# посмотрим его характеристики

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

dataset = sns.load_dataset('iris')
print(dataset.shape)
print(dataset.head())
# Out:
# (150, 5)
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# Далее, разделим наши данные на атрибуты и метки, а затем выделим в
# общей совокупности полученных данных обучающие и тестовые наборы.
# Таким образом, мы можем обучить наш алгоритм на одном наборе данных,
# а затем протестировать его на совершенно на другом наборе, который
# алгоритм еще не видел. Это дает вам более точное представление о том,
# как на самом деле будет работать ваш обученный алгоритм.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    # так как iris это пандас таблица, для неё не нужно указывать iloc
    dataset.iloc[:, :-1], # берём все колонки кроме последней в признаки
    dataset.iloc[:, -1], # последнюю в целевую переменную (класс)
    test_size= 0.20 # размер тестовой выборки 20 %
)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((120, 4), (30, 4), (120,), (30,))

# %%
X_train.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 20            5.4          3.4           1.7          0.2
# 108           6.7          2.5           5.8          1.8
# 135           7.7          3.0           6.1          2.3
# 10            5.4          3.7           1.5          0.2
# 78            6.0          2.9           4.5          1.5

# %%
y_train.head()
# Out:
# 20         setosa
# 108     virginica
# 135     virginica
# 10         setosa
# 78     versicolor
# Name: species, dtype: object

# %% [markdown]
# После того, как данные были разделены на обучающие и тестовые наборы,
# последний шаг состоит в том, чтобы обучить алгоритм дерева решений на
# этих данных и сделать прогнозы. Scikit-Learn содержит библиотеку tree ,
# которая содержит встроенные классы/методы для различных алгоритмов
# дерева решений. Поскольку мы собираемся выполнить здесь задачу
# классификации, мы будем использовать класс DecisionTreeClassifier для
# этого примера. Метод fit этого класса вызывается для обучения алгоритма
# на обучающих данных, которые передаются в качестве параметра методу
# fit . Выполним следующий сценарий для обучения алгоритма.

# %%
from sklearn.tree import DecisionTreeClassifier
classifier = DecisionTreeClassifier()
classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# построим дерево решений
from sklearn import tree

tree.plot_tree(classifier)
# Out:
# [Text(0.375, 0.9, 'x[2] <= 2.6\ngini = 0.666\nsamples = 120\nvalue = [41, 38, 41]'),
#  Text(0.25, 0.7, 'gini = 0.0\nsamples = 41\nvalue = [41, 0, 0]'),
#  Text(0.5, 0.7, 'x[3] <= 1.65\ngini = 0.499\nsamples = 79\nvalue = [0, 38, 41]'),
#  Text(0.25, 0.5, 'x[2] <= 5.35\ngini = 0.097\nsamples = 39\nvalue = [0, 37, 2]'),
#  Text(0.125, 0.3, 'gini = 0.0\nsamples = 37\nvalue = [0, 37, 0]'),
#  Text(0.375, 0.3, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.75, 0.5, 'x[2] <= 4.85\ngini = 0.049\nsamples = 40\nvalue = [0, 1, 39]'),
#  Text(0.625, 0.3, 'x[1] <= 3.0\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(0.5, 0.1, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(0.75, 0.1, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(0.875, 0.3, 'gini = 0.0\nsamples = 37\nvalue = [0, 0, 37]')]

# %% [markdown]
# Теперь, когда наш классификатор обучен, давайте сделаем прогнозы по
# тестовым данным. Для составления прогнозов используется метод predict
# класса Decision Tree Classifier. Взгляните на следующий код для
# использования.

# %%
y_pred = classifier.predict(X_test)
y_pred
# Out:
# array(['versicolor', 'virginica', 'versicolor', 'virginica', 'virginica',
#        'versicolor', 'virginica', 'setosa', 'setosa', 'versicolor',
#        'virginica', 'versicolor', 'versicolor', 'versicolor', 'setosa',
#        'versicolor', 'versicolor', 'setosa', 'setosa', 'setosa',
#        'virginica', 'virginica', 'setosa', 'versicolor', 'virginica',
#        'versicolor', 'setosa', 'setosa', 'versicolor', 'versicolor'],
#       dtype=object)

# %% [markdown]
# На данный момент мы обучили наш алгоритм и сделали некоторые
# прогнозы. Теперь посмотрим, насколько точен наш алгоритм. Для задач
# классификации обычно используются такие метрики, как матрица
# путаницы, точность. Библиотека Scikit-Learn metrics содержит методы
# classification_report и confusion_matrix, которые могут быть использованы
# для расчета этих метрик

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[ 9  0  0]
#  [ 0 11  1]
#  [ 0  2  7]]
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00         9
#   versicolor       0.85      0.92      0.88        12
#    virginica       0.88      0.78      0.82         9
#
#     accuracy                           0.90        30
#    macro avg       0.91      0.90      0.90        30
# weighted avg       0.90      0.90      0.90        30

# %% [markdown]
# Из матрицы оценок алгоритма вы можете видеть, что из 30 тестовых
# экземпляров наш алгоритм неправильно классифицировал только 3. Это
# приблизительно 91 % точности.

# %% [markdown]
# 1.3.1 Задание № 1:
#
# Постройте классификатор на основе дерева принятия решений
# следующего датасета:
#
# x = np.array([[-1, 1], [-2, -1], [-3, -2], [1,1], [2, 1], [3, 2]])
# target = [0,0,0,1,1,1]

# %%
from sklearn.model_selection import train_test_split

X = np.array([[-1,-1],[-2,-1],[-3,-2],[1,1],[2,1],[3,2]])
target = [0,0,0,1,1,1]

X_train, X_test, y_train, y_test = train_test_split(
    # поскольку ирис это pandas-таблица, для нее нужно указать iloc
    X,    # все колонки кроме последней - в признаки
    target, # последнюю в целевую переменную (класс)
    test_size = 0.20 # размер тестовой выборки 20%
)

X_train,'\n', X_test,'\n', y_train, '\n', y_test
# Out:
# (array([[ 1,  1],
#         [-1, -1],
#         [ 2,  1],
#         [ 3,  2]]),
#  '\n',
#  array([[-2, -1],
#         [-3, -2]]),
#  '\n',
#  [1, 0, 1, 1],
#  '\n',
#  [0, 0])

# %%
from sklearn.tree import DecisionTreeClassifier

classifier = DecisionTreeClassifier()
classifier.fit(X_train, y_train)

from sklearn import tree

tree.plot_tree(classifier)
# Out:
# [Text(0.5, 0.75, 'x[1] <= 0.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(0.25, 0.25, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(0.75, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]')]

# %%
y_pred = classifier.predict(X_test)
y_pred
# Out:
# array([0, 0])

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[2]]
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#
#     accuracy                           1.00         2
#    macro avg       1.00      1.00      1.00         2
# weighted avg       1.00      1.00      1.00         2

# %% [markdown]
# # 1.4 Дерево решений для регрессии

# %% [markdown]
# 1.4.1 Пример
#
# Постойте регрессию с использованием дерева решений, реализованного в
# Python.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/AnnaShestova/salary-years-simple-linear-regression/master/Salary_Data.csv'
dataset = pd.read_csv(url)
dataset.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
# Исследуем набор данных
print(dataset.shape)
dataset.describe()
# Out:
# (30, 2)
#        YearsExperience         Salary
# count        30.000000      30.000000
# mean          5.313333   76003.000000
# std           2.837888   27414.429785
# min           1.100000   37731.000000
# 25%           3.200000   56720.750000
# 50%           4.700000   65237.000000
# 75%           7.700000  100544.750000
# max          10.500000  122391.000000

# %%
# нарисуем точечную диаграмму
plt.scatter(dataset['YearsExperience'], dataset['Salary'], color = 'b', label = 'Заработная Плата')
plt.xlabel("Опыт(лет)")
plt.ylabel("Заработная Плата")
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor

X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 1].values
print(X)
print(y)

# Теперь когда у нас есть атрибуты и метрики, необходимо разделить их на обучающий и тестовый наборы
# Привидённый фрагмент разделяет 80% данных на обучающий набор, а 20% данных - на набор тестов

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state= 0 )

# Далее можно обучить алгоритм линейной регрессии
# необходимо импортировать класс LinearRegression, создать его экземпляр и вызвать метод fit()
regressor = DecisionTreeRegressor()
regressor.fit(X_train, y_train)
# Out:
# [[ 1.1]
#  [ 1.3]
#  [ 1.5]
#  [ 2. ]
#  [ 2.2]
#  [ 2.9]
#  [ 3. ]
#  [ 3.2]
#  [ 3.2]
#  [ 3.7]
#  [ 3.9]
#  [ 4. ]
#  [ 4. ]
#  [ 4.1]
#  [ 4.5]
#  [ 4.9]
#  [ 5.1]
#  [ 5.3]
#  [ 5.9]
#  [ 6. ]
#  [ 6.8]
#  [ 7.1]
#  [ 7.9]
#  [ 8.2]
#  [ 8.7]
#  [ 9. ]
#  [ 9.5]
#  [ 9.6]
#  [10.3]
#  [10.5]]
# [ 39343.  46205.  37731.  43525.  39891.  56642.  60150.  54445.  64445.
#   57189.  63218.  55794.  56957.  57081.  61111.  67938.  66029.  83088.
#   81363.  93940.  91738.  98273. 101302. 113812. 109431. 105582. 116969.
#  112635. 122391. 121872.]
# DecisionTreeRegressor()

# %%
from sklearn import tree

tree.plot_tree(regressor)
# Out:
# [Text(0.4956896551724138, 0.9375, 'x[0] <= 5.2\nsquared_error = 614737637.832\nsamples = 24\nvalue = 73886.208'),
#  Text(0.20689655172413793, 0.8125, 'x[0] <= 2.55\nsquared_error = 81200345.857\nsamples = 14\nvalue = 54976.0'),
#  Text(0.06896551724137931, 0.6875, 'x[0] <= 1.2\nsquared_error = 7820714.0\nsamples = 4\nvalue = 42241.0'),
#  Text(0.034482758620689655, 0.5625, 'squared_error = 0.0\nsamples = 1\nvalue = 39343.0'),
#  Text(0.10344827586206896, 0.5625, 'x[0] <= 2.1\nsquared_error = 6694994.667\nsamples = 3\nvalue = 43207.0'),
#  Text(0.06896551724137931, 0.4375, 'x[0] <= 1.65\nsquared_error = 1795600.0\nsamples = 2\nvalue = 44865.0'),
#  Text(0.034482758620689655, 0.3125, 'squared_error = 0.0\nsamples = 1\nvalue = 46205.0'),
#  Text(0.10344827586206896, 0.3125, 'squared_error = 0.0\nsamples = 1\nvalue = 43525.0'),
#  Text(0.13793103448275862, 0.4375, 'squared_error = 0.0\nsamples = 1\nvalue = 39891.0'),
#  Text(0.3448275862068966, 0.6875, 'x[0] <= 4.7\nsquared_error = 19731272.6\nsamples = 10\nvalue = 60070.0'),
#  Text(0.27586206896551724, 0.5625, 'x[0] <= 4.25\nsquared_error = 9499922.484\nsamples = 8\nvalue = 58341.625'),
#  Text(0.2413793103448276, 0.4375, 'x[0] <= 3.45\nsquared_error = 9604901.143\nsamples = 7\nvalue = 57946.0'),
#  Text(0.1724137931034483, 0.3125, 'x[0] <= 2.95\nsquared_error = 14313358.25\nsamples = 4\nvalue = 58920.5'),
#  Text(0.13793103448275862, 0.1875, 'squared_error = 0.0\nsamples = 1\nvalue = 56642.0'),
#  Text(0.20689655172413793, 0.1875, 'x[0] <= 3.1\nsquared_error = 16777116.667\nsamples = 3\nvalue = 59680.0'),
#  Text(0.1724137931034483, 0.0625, 'squared_error = 0.0\nsamples = 1\nvalue = 60150.0'),
#  Text(0.2413793103448276, 0.0625, 'squared_error = 25000000.0\nsamples = 2\nvalue = 59445.0'),
#  Text(0.3103448275862069, 0.3125, 'x[0] <= 3.85\nsquared_error = 372490.889\nsamples = 3\nvalue = 56646.667'),
#  Text(0.27586206896551724, 0.1875, 'squared_error = 0.0\nsamples = 1\nvalue = 57189.0'),
#  Text(0.3448275862068966, 0.1875, 'squared_error = 338142.25\nsamples = 2\nvalue = 56375.5'),
#  Text(0.3103448275862069, 0.4375, 'squared_error = 0.0\nsamples = 1\nvalue = 61111.0'),
#  Text(0.41379310344827586, 0.5625, 'x[0] <= 5.0\nsquared_error = 911070.25\nsamples = 2\nvalue = 66983.5'),
#  Text(0.3793103448275862, 0.4375, 'squared_error = 0.0\nsamples = 1\nvalue = 67938.0'),
#  Text(0.4482758620689655, 0.4375, 'squared_error = 0.0\nsamples = 1\nvalue = 66029.0'),
#  Text(0.7844827586206896, 0.8125, 'x[0] <= 8.05\nsquared_error = 160167356.45\nsamples = 10\nvalue = 100360.5'),
#  Text(0.6379310344827587, 0.6875, 'x[0] <= 5.95\nsquared_error = 53566814.556\nsamples = 6\nvalue = 91617.333'),
#  Text(0.5517241379310345, 0.5625, 'x[0] <= 5.6\nsquared_error = 743906.25\nsamples = 2\nvalue = 82225.5'),
#  Text(0.5172413793103449, 0.4375, 'squared_error = 0.0\nsamples = 1\nvalue = 83088.0'),
#  Text(0.5862068965517241, 0.4375, 'squared_error = 0.0\nsamples = 1\nvalue = 81363.0'),
#  Text(0.7241379310344828, 0.5625, 'x[0] <= 6.95\nsquared_error = 13823368.688\nsamples = 4\nvalue = 96313.25'),
#  Text(0.6551724137931034, 0.4375, 'x[0] <= 6.4\nsquared_error = 1212201.0\nsamples = 2\nvalue = 92839.0'),
#  Text(0.6206896551724138, 0.3125, 'squared_error = 0.0\nsamples = 1\nvalue = 93940.0'),
#  Text(0.6896551724137931, 0.3125, 'squared_error = 0.0\nsamples = 1\nvalue = 91738.0'),
#  Text(0.7931034482758621, 0.4375, 'x[0] <= 7.5\nsquared_error = 2293710.25\nsamples = 2\nvalue = 99787.5'),
#  Text(0.7586206896551724, 0.3125, 'squared_error = 0.0\nsamples = 1\nvalue = 98273.0'),
#  Text(0.8275862068965517, 0.3125, 'squared_error = 0.0\nsamples = 1\nvalue = 101302.0'),
#  Text(0.9310344827586207, 0.6875, 'x[0] <= 10.05\nsquared_error = 33407056.688\nsamples = 4\nvalue = 113475.25'),
#  Text(0.896551724137931, 0.5625, 'x[0] <= 8.6\nsquared_error = 13207004.222\nsamples = 3\nvalue = 110676.333'),
#  Text(0.8620689655172413, 0.4375, 'squared_error = 0.0\nsamples = 1\nvalue = 113812.0'),
#  Text(0.9310344827586207, 0.4375, 'x[0] <= 9.3\nsquared_error = 12436202.25\nsamples = 2\nvalue = 109108.5'),
#  Text(0.896551724137931, 0.3125, 'squared_error = 0.0\nsamples = 1\nvalue = 105582.0'),
#  Text(0.9655172413793104, 0.3125, 'squared_error = 0.0\nsamples = 1\nvalue = 112635.0'),
#  Text(0.9655172413793104, 0.5625, 'squared_error = 0.0\nsamples = 1\nvalue = 121872.0')]

# %% [markdown]
# Построим прогноз:

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([ 46205. , 121872. ,  56375.5,  56375.5, 112635. , 105582. ])

# %% [markdown]
# Теперь сравним некоторые из наших прогнозируемых значений с
# фактическими значениями:

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
# Out:
#      Actual  Predicted
# 0   37731.0    46205.0
# 1  122391.0   121872.0
# 2   57081.0    56375.5
# 3   63218.0    56375.5
# 4  116969.0   112635.0
# 5  109431.0   105582.0

# %% [markdown]
# Расчитаем среднюю абсолютную и среднеквадратичную ошибку
# регрессии:

# %%
from sklearn import metrics

print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_pred))
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Squared Error:  25498988.416666668
# Mean Absolute Error:  4120.666666666667

# %% [markdown]
# 1.4.1 Задание № 2:
#
# Задание. Постройте модель регрессии для данных из предыдущей рабочей
# тетради.Для примера можно взять потребления газа (в миллионах
# галлонов) в 48 штатах США или набор данных о качестве красного вина:
# https://raw.githubusercontent.com/likarajo/petrol_consumption/master/data/pet
# rol_consumption.csv
# https://raw.githubusercontent.com/aniruddhachoudhury/Red-WineQuality/master/winequality-red.csv
# Постройте прогноз. Оцените точность модели

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

url = 'https://raw.githubusercontent.com/aniruddhachoudhury/Red-Wine-Quality/master/winequality-red.csv'
dataset = pd.read_csv(url)
dataset.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# 3      9.8        6
# 4      9.4        5

# %%
# исследуем набор данных:
print(dataset.shape)
# Out:
# (1599, 12)

# %%
# исследуем набор данных:
print(dataset.describe())
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# min       0.012000             1.000000              6.000000     0.990070
# 25%       0.070000             7.000000             22.000000     0.995600
# 50%       0.079000            14.000000             38.000000     0.996750
# 75%       0.090000            21.000000             62.000000     0.997835
# max       0.611000            72.000000            289.000000     1.003690
#
#                 pH    sulphates      alcohol      quality
# count  1599.000000  1599.000000  1599.000000  1599.000000
# mean      3.311113     0.658149    10.422983     5.636023
# std       0.154386     0.169507     1.065668     0.807569
# min       2.740000     0.330000     8.400000     3.000000
# 25%       3.210000     0.550000     9.500000     5.000000
# 50%       3.310000     0.620000    10.200000     6.000000
# 75%       3.400000     0.730000    11.100000     6.000000
# max       4.010000     2.000000    14.900000     8.000000

# %%
# нарисуем точечную диаграмму
plt.scatter(dataset['chlorides'], dataset['alcohol'], color = 'r')
plt.xlabel('Хлориды')
plt.ylabel('Алкоголь')
plt.show()

# %%
from sklearn.tree import DecisionTreeRegressor

X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, 1].values
print(X)
print(y)

# Теперь когда у нас есть атрибуты и метрики, необходимо разделить их на обучающий и тестовый наборы
# Привидённый фрагмент разделяет 80% данных на обучающий набор, а 20% данных - на набор тестов

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state= 0 )

# Далее можно обучить алгоритм линейной регрессии
# необходимо импортировать класс LinearRegression, создать его экземпляр и вызвать метод fit()
regressor = DecisionTreeRegressor()
regressor.fit(X_train, y_train)
# Out:
# [[ 7.4    0.7    0.    ...  3.51   0.56   9.4  ]
#  [ 7.8    0.88   0.    ...  3.2    0.68   9.8  ]
#  [ 7.8    0.76   0.04  ...  3.26   0.65   9.8  ]
#  ...
#  [ 6.3    0.51   0.13  ...  3.42   0.75  11.   ]
#  [ 5.9    0.645  0.12  ...  3.57   0.71  10.2  ]
#  [ 6.     0.31   0.47  ...  3.39   0.66  11.   ]]
# [0.7   0.88  0.76  ... 0.51  0.645 0.31 ]
# DecisionTreeRegressor()

# %%
from sklearn import tree

tree.plot_tree(regressor)
# Out:
# [Text(0.414161811440678, 0.9615384615384616, 'x[1] <= 0.535\nsquared_error = 0.033\nsamples = 1279\nvalue = 0.53'),
#  Text(0.1684322033898305, 0.8846153846153846, 'x[1] <= 0.375\nsquared_error = 0.008\nsamples = 666\nvalue = 0.392'),
#  Text(0.08792372881355932, 0.8076923076923077, 'x[1] <= 0.285\nsquared_error = 0.003\nsamples = 263\nvalue = 0.301'),
#  Text(0.04343220338983051, 0.7307692307692307, 'x[1] <= 0.225\nsquared_error = 0.002\nsamples = 90\nvalue = 0.24'),
#  Text(0.019067796610169493, 0.6538461538461539, 'x[1] <= 0.17\nsquared_error = 0.001\nsamples = 25\nvalue = 0.186'),
#  Text(0.00847457627118644, 0.5769230769230769, 'x[5] <= 13.5\nsquared_error = 0.0\nsamples = 4\nvalue = 0.13'),
#  Text(0.00423728813559322, 0.5, 'squared_error = 0.0\nsamples = 3\nvalue = 0.12'),
#  Text(0.012711864406779662, 0.5, 'squared_error = -0.0\nsamples = 1\nvalue = 0.16'),
#  Text(0.029661016949152543, 0.5769230769230769, 'x[1] <= 0.195\nsquared_error = 0.0\nsamples = 21\nvalue = 0.197'),
#  Text(0.0211864406779661, 0.5, 'x[1] <= 0.185\nsquared_error = 0.0\nsamples = 10\nvalue = 0.182'),
#  Text(0.01694915254237288, 0.4230769230769231, 'squared_error = 0.0\nsamples = 8\nvalue = 0.18'),
#  Text(0.025423728813559324, 0.4230769230769231, 'squared_error = 0.0\nsamples = 2\nvalue = 0.19'),
#  Text(0.038135593220338986, 0.5, 'x[1] <= 0.215\nsquared_error = 0.0\nsamples = 11\nvalue = 0.211'),
#  Text(0.03389830508474576, 0.4230769230769231, 'x[8] <= 3.265\nsquared_error = 0.0\nsamples = 7\nvalue = 0.206'),
#  Text(0.029661016949152543, 0.34615384615384615, 'squared_error = -0.0\nsamples = 4\nvalue = 0.21'),
#  Text(0.038135593220338986, 0.34615384615384615, 'squared_error = 0.0\nsamples = 3\nvalue = 0.2'),
#  Text(0.0423728813559322, 0.4230769230769231, 'squared_error = -0.0\nsamples = 4\nvalue = 0.22'),
#  Text(0.06779661016949153, 0.6538461538461539, 'x[1] <= 0.255\nsquared_error = 0.0\nsamples = 65\nvalue = 0.26'),
#  Text(0.059322033898305086, 0.5769230769230769, 'x[1] <= 0.245\nsquared_error = 0.0\nsamples = 23\nvalue = 0.241'),
#  Text(0.05508474576271186, 0.5, 'x[1] <= 0.235\nsquared_error = 0.0\nsamples = 16\nvalue = 0.237'),
#  Text(0.05084745762711865, 0.4230769230769231, 'squared_error = -0.0\nsamples = 5\nvalue = 0.23'),
#  Text(0.059322033898305086, 0.4230769230769231, 'squared_error = -0.0\nsamples = 11\nvalue = 0.24'),
#  Text(0.0635593220338983, 0.5, 'squared_error = 0.0\nsamples = 7\nvalue = 0.25'),
#  Text(0.07627118644067797, 0.5769230769230769, 'x[1] <= 0.275\nsquared_error = 0.0\nsamples = 42\nvalue = 0.271'),
#  Text(0.07203389830508475, 0.5, 'x[1] <= 0.265\nsquared_error = 0.0\nsamples = 23\nvalue = 0.264'),
#  Text(0.06779661016949153, 0.4230769230769231, 'squared_error = 0.0\nsamples = 14\nvalue = 0.26'),
#  Text(0.07627118644067797, 0.4230769230769231, 'squared_error = 0.0\nsamples = 9\nvalue = 0.27'),
#  Text(0.08050847457627118, 0.5, 'squared_error = 0.0\nsamples = 19\nvalue = 0.28'),
#  Text(0.13241525423728814, 0.7307692307692307, 'x[1] <= 0.335\nsquared_error = 0.001\nsamples = 173\nvalue = 0.333'),
#  Text(0.11228813559322035, 0.6538461538461539, 'x[1] <= 0.312\nsquared_error = 0.0\nsamples = 86\nvalue = 0.311'),
#  Text(0.09745762711864407, 0.5769230769230769, 'x[1] <= 0.303\nsquared_error = 0.0\nsamples = 50\nvalue = 0.302'),
#  Text(0.08898305084745763, 0.5, 'x[1] <= 0.295\nsquared_error = 0.0\nsamples = 26\nvalue = 0.295'),
#  Text(0.0847457627118644, 0.4230769230769231, 'squared_error = -0.0\nsamples = 12\nvalue = 0.29'),
#  Text(0.09322033898305085, 0.4230769230769231, 'squared_error = 0.0\nsamples = 14\nvalue = 0.3'),
#  Text(0.1059322033898305, 0.5, 'x[3] <= 1.3\nsquared_error = 0.0\nsamples = 24\nvalue = 0.31'),
#  Text(0.1016949152542373, 0.4230769230769231, 'squared_error = 0.0\nsamples = 2\nvalue = 0.305'),
#  Text(0.11016949152542373, 0.4230769230769231, 'squared_error = 0.0\nsamples = 22\nvalue = 0.31'),
#  Text(0.1271186440677966, 0.5769230769230769, 'x[1] <= 0.325\nsquared_error = 0.0\nsamples = 36\nvalue = 0.324'),
#  Text(0.1228813559322034, 0.5, 'x[1] <= 0.317\nsquared_error = 0.0\nsamples = 20\nvalue = 0.32'),
#  Text(0.11864406779661017, 0.4230769230769231, 'squared_error = 0.0\nsamples = 2\nvalue = 0.315'),
#  Text(0.1271186440677966, 0.4230769230769231, 'squared_error = -0.0\nsamples = 18\nvalue = 0.32'),
#  Text(0.13135593220338984, 0.5, 'squared_error = 0.0\nsamples = 16\nvalue = 0.33'),
#  Text(0.15254237288135594, 0.6538461538461539, 'x[1] <= 0.355\nsquared_error = 0.0\nsamples = 87\nvalue = 0.355'),
#  Text(0.1440677966101695, 0.5769230769230769, 'x[1] <= 0.345\nsquared_error = 0.0\nsamples = 39\nvalue = 0.345'),
#  Text(0.13983050847457626, 0.5, 'squared_error = -0.0\nsamples = 21\nvalue = 0.34'),
#  Text(0.1483050847457627, 0.5, 'x[9] <= 0.465\nsquared_error = 0.0\nsamples = 18\nvalue = 0.35'),
#  Text(0.1440677966101695, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 0.35'),
#  Text(0.15254237288135594, 0.4230769230769231, 'squared_error = 0.0\nsamples = 17\nvalue = 0.35'),
#  Text(0.16101694915254236, 0.5769230769230769, 'x[1] <= 0.363\nsquared_error = 0.0\nsamples = 48\nvalue = 0.364'),
#  Text(0.15677966101694915, 0.5, 'squared_error = 0.0\nsamples = 29\nvalue = 0.36'),
#  Text(0.1652542372881356, 0.5, 'x[8] <= 3.35\nsquared_error = 0.0\nsamples = 19\nvalue = 0.37'),
#  Text(0.16101694915254236, 0.4230769230769231, 'squared_error = -0.0\nsamples = 18\nvalue = 0.37'),
#  Text(0.1694915254237288, 0.4230769230769231, 'squared_error = -0.0\nsamples = 1\nvalue = 0.365'),
#  Text(0.2489406779661017, 0.8076923076923077, 'x[1] <= 0.455\nsquared_error = 0.002\nsamples = 403\nvalue = 0.451'),
#  Text(0.211864406779661, 0.7307692307692307, 'x[1] <= 0.412\nsquared_error = 0.0\nsamples = 217\nvalue = 0.413'),
#  Text(0.19491525423728814, 0.6538461538461539, 'x[1] <= 0.395\nsquared_error = 0.0\nsamples = 113\nvalue = 0.394'),
#  Text(0.1864406779661017, 0.5769230769230769, 'x[1] <= 0.385\nsquared_error = 0.0\nsamples = 59\nvalue = 0.385'),
#  Text(0.18220338983050846, 0.5, 'x[7] <= 0.994\nsquared_error = 0.0\nsamples = 31\nvalue = 0.38'),
#  Text(0.17796610169491525, 0.4230769230769231, 'squared_error = 0.0\nsamples = 2\nvalue = 0.38'),
#  Text(0.1864406779661017, 0.4230769230769231, 'squared_error = -0.0\nsamples = 29\nvalue = 0.38'),
#  Text(0.1906779661016949, 0.5, 'squared_error = -0.0\nsamples = 28\nvalue = 0.39'),
#  Text(0.2033898305084746, 0.5769230769230769, 'x[1] <= 0.405\nsquared_error = 0.0\nsamples = 54\nvalue = 0.405'),
#  Text(0.19915254237288135, 0.5, 'squared_error = 0.0\nsamples = 28\nvalue = 0.4'),
#  Text(0.2076271186440678, 0.5, 'squared_error = -0.0\nsamples = 26\nvalue = 0.41'),
#  Text(0.2288135593220339, 0.6538461538461539, 'x[1] <= 0.435\nsquared_error = 0.0\nsamples = 104\nvalue = 0.433'),
#  Text(0.22033898305084745, 0.5769230769230769, 'x[1] <= 0.425\nsquared_error = 0.0\nsamples = 66\nvalue = 0.425'),
#  Text(0.21610169491525424, 0.5, 'x[1] <= 0.417\nsquared_error = 0.0\nsamples = 29\nvalue = 0.42'),
#  Text(0.211864406779661, 0.4230769230769231, 'squared_error = 0.0\nsamples = 2\nvalue = 0.415'),
#  Text(0.22033898305084745, 0.4230769230769231, 'squared_error = 0.0\nsamples = 27\nvalue = 0.42'),
#  Text(0.2245762711864407, 0.5, 'squared_error = -0.0\nsamples = 37\nvalue = 0.43'),
#  Text(0.23728813559322035, 0.5769230769230769, 'x[1] <= 0.445\nsquared_error = 0.0\nsamples = 38\nvalue = 0.445'),
#  Text(0.2330508474576271, 0.5, 'squared_error = -0.0\nsamples = 20\nvalue = 0.44'),
#  Text(0.24152542372881355, 0.5, 'x[6] <= 9.0\nsquared_error = 0.0\nsamples = 18\nvalue = 0.45'),
#  Text(0.23728813559322035, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 0.45'),
#  Text(0.2457627118644068, 0.4230769230769231, 'squared_error = 0.0\nsamples = 17\nvalue = 0.45'),
#  Text(0.2860169491525424, 0.7307692307692307, 'x[1] <= 0.495\nsquared_error = 0.001\nsamples = 186\nvalue = 0.495'),
#  Text(0.2669491525423729, 0.6538461538461539, 'x[1] <= 0.472\nsquared_error = 0.0\nsamples = 94\nvalue = 0.476'),
#  Text(0.2542372881355932, 0.5769230769230769, 'x[1] <= 0.465\nsquared_error = 0.0\nsamples = 42\nvalue = 0.464'),
#  Text(0.25, 0.5, 'squared_error = -0.0\nsamples = 27\nvalue = 0.46'),
#  Text(0.2584745762711864, 0.5, 'x[6] <= 24.0\nsquared_error = 0.0\nsamples = 15\nvalue = 0.47'),
#  Text(0.2542372881355932, 0.4230769230769231, 'squared_error = 0.0\nsamples = 2\nvalue = 0.47'),
#  Text(0.2627118644067797, 0.4230769230769231, 'squared_error = 0.0\nsamples = 13\nvalue = 0.47'),
#  Text(0.2796610169491525, 0.5769230769230769, 'x[1] <= 0.485\nsquared_error = 0.0\nsamples = 52\nvalue = 0.485'),
#  Text(0.2754237288135593, 0.5, 'x[3] <= 1.5\nsquared_error = 0.0\nsamples = 23\nvalue = 0.48'),
#  Text(0.2711864406779661, 0.4230769230769231, 'squared_error = 0.0\nsamples = 2\nvalue = 0.475'),
#  Text(0.2796610169491525, 0.4230769230769231, 'squared_error = -0.0\nsamples = 21\nvalue = 0.48'),
#  Text(0.2838983050847458, 0.5, 'squared_error = 0.0\nsamples = 29\nvalue = 0.49'),
#  Text(0.3050847457627119, 0.6538461538461539, 'x[1] <= 0.515\nsquared_error = 0.0\nsamples = 92\nvalue = 0.514'),
#  Text(0.2966101694915254, 0.5769230769230769, 'x[1] <= 0.505\nsquared_error = 0.0\nsamples = 46\nvalue = 0.504'),
#  Text(0.2923728813559322, 0.5, 'x[5] <= 4.0\nsquared_error = 0.0\nsamples = 28\nvalue = 0.5'),
#  Text(0.288135593220339, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 0.5'),
#  Text(0.2966101694915254, 0.4230769230769231, 'squared_error = 0.0\nsamples = 27\nvalue = 0.5'),
#  Text(0.3008474576271186, 0.5, 'squared_error = -0.0\nsamples = 18\nvalue = 0.51'),
#  Text(0.3135593220338983, 0.5769230769230769, 'x[1] <= 0.525\nsquared_error = 0.0\nsamples = 46\nvalue = 0.525'),
#  Text(0.3093220338983051, 0.5, 'x[8] <= 2.945\nsquared_error = 0.0\nsamples = 24\nvalue = 0.52'),
#  Text(0.3050847457627119, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 0.52'),
#  Text(0.3135593220338983, 0.4230769230769231, 'x[9] <= 0.5\nsquared_error = 0.0\nsamples = 23\nvalue = 0.52'),
#  Text(0.3093220338983051, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 0.52'),
#  Text(0.3177966101694915, 0.34615384615384615, 'x[2] <= 0.035\nsquared_error = 0.0\nsamples = 22\nvalue = 0.52'),
#  Text(0.3135593220338983, 0.2692307692307692, 'squared_error = 0.0\nsamples = 2\nvalue = 0.52'),
#  Text(0.3220338983050847, 0.2692307692307692, 'x[0] <= 6.55\nsquared_error = 0.0\nsamples = 20\nvalue = 0.52'),
#  Text(0.3177966101694915, 0.19230769230769232, 'squared_error = 0.0\nsamples = 2\nvalue = 0.52'),
#  Text(0.326271186440678, 0.19230769230769232, 'x[4] <= 0.067\nsquared_error = 0.0\nsamples = 18\nvalue = 0.52'),
#  Text(0.3220338983050847, 0.11538461538461539, 'squared_error = 0.0\nsamples = 2\nvalue = 0.52'),
#  Text(0.3305084745762712, 0.11538461538461539, 'x[5] <= 4.5\nsquared_error = 0.0\nsamples = 16\nvalue = 0.52'),
#  Text(0.326271186440678, 0.038461538461538464, 'squared_error = 0.0\nsamples = 1\nvalue = 0.52'),
#  Text(0.3347457627118644, 0.038461538461538464, 'squared_error = 0.0\nsamples = 15\nvalue = 0.52'),
#  Text(0.3177966101694915, 0.5, 'squared_error = -0.0\nsamples = 22\nvalue = 0.53'),
#  Text(0.6598914194915254, 0.8846153846153846, 'x[1] <= 0.762\nsquared_error = 0.018\nsamples = 613\nvalue = 0.68'),
#  Text(0.4631885593220339, 0.8076923076923077, 'x[1] <= 0.637\nsquared_error = 0.003\nsamples = 494\nvalue = 0.628'),
#  Text(0.3940677966101695, 0.7307692307692307, 'x[1] <= 0.587\nsquared_error = 0.001\nsamples = 293\nvalue = 0.587'),
#  Text(0.3601694915254237, 0.6538461538461539, 'x[1] <= 0.562\nsquared_error = 0.0\nsamples = 137\nvalue = 0.561'),
#  Text(0.3432203389830508, 0.5769230769230769, 'x[1] <= 0.555\nsquared_error = 0.0\nsamples = 78\nvalue = 0.55'),
#  Text(0.3389830508474576, 0.5, 'x[1] <= 0.543\nsquared_error = 0.0\nsamples = 49\nvalue = 0.544'),
#  Text(0.3305084745762712, 0.4230769230769231, 'x[0] <= 6.8\nsquared_error = 0.0\nsamples = 28\nvalue = 0.54'),
#  Text(0.326271186440678, 0.34615384615384615, 'squared_error = 0.0\nsamples = 5\nvalue = 0.54'),
#  Text(0.3347457627118644, 0.34615384615384615, 'x[0] <= 7.4\nsquared_error = 0.0\nsamples = 23\nvalue = 0.54'),
#  Text(0.3305084745762712, 0.2692307692307692, 'squared_error = 0.0\nsamples = 5\nvalue = 0.54'),
#  Text(0.3389830508474576, 0.2692307692307692, 'squared_error = 0.0\nsamples = 18\nvalue = 0.54'),
#  Text(0.3474576271186441, 0.4230769230769231, 'x[1] <= 0.548\nsquared_error = 0.0\nsamples = 21\nvalue = 0.549'),
#  Text(0.3432203389830508, 0.34615384615384615, 'squared_error = 0.0\nsamples = 5\nvalue = 0.545'),
#  Text(0.3516949152542373, 0.34615384615384615, 'squared_error = 0.0\nsamples = 16\nvalue = 0.55'),
#  Text(0.3474576271186441, 0.5, 'squared_error = -0.0\nsamples = 29\nvalue = 0.56'),
#  Text(0.3771186440677966, 0.5769230769230769, 'x[1] <= 0.577\nsquared_error = 0.0\nsamples = 59\nvalue = 0.576'),
#  Text(0.3686440677966102, 0.5, 'x[1] <= 0.572\nsquared_error = 0.0\nsamples = 27\nvalue = 0.57'),
#  Text(0.3644067796610169, 0.4230769230769231, 'x[1] <= 0.567\nsquared_error = 0.0\nsamples = 24\nvalue = 0.57'),
#  Text(0.3601694915254237, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 0.565'),
#  Text(0.3686440677966102, 0.34615384615384615, 'squared_error = -0.0\nsamples = 23\nvalue = 0.57'),
#  Text(0.3728813559322034, 0.4230769230769231, 'squared_error = -0.0\nsamples = 3\nvalue = 0.575'),
#  Text(0.3855932203389831, 0.5, 'x[1] <= 0.582\nsquared_error = 0.0\nsamples = 32\nvalue = 0.58'),
#  Text(0.3813559322033898, 0.4230769230769231, 'squared_error = 0.0\nsamples = 29\nvalue = 0.58'),
#  Text(0.3898305084745763, 0.4230769230769231, 'squared_error = -0.0\nsamples = 3\nvalue = 0.585'),
#  Text(0.4279661016949153, 0.6538461538461539, 'x[1] <= 0.613\nsquared_error = 0.0\nsamples = 156\nvalue = 0.609'),
#  Text(0.4110169491525424, 0.5769230769230769, 'x[1] <= 0.598\nsquared_error = 0.0\nsamples = 95\nvalue = 0.599'),
#  Text(0.4025423728813559, 0.5, 'x[1] <= 0.593\nsquared_error = 0.0\nsamples = 30\nvalue = 0.59'),
#  Text(0.3983050847457627, 0.4230769230769231, 'squared_error = 0.0\nsamples = 29\nvalue = 0.59'),
#  Text(0.4067796610169492, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 0.595'),
#  Text(0.4194915254237288, 0.5, 'x[1] <= 0.603\nsquared_error = 0.0\nsamples = 65\nvalue = 0.603'),
#  Text(0.4152542372881356, 0.4230769230769231, 'squared_error = -0.0\nsamples = 41\nvalue = 0.6'),
#  Text(0.423728813559322, 0.4230769230769231, 'x[1] <= 0.608\nsquared_error = 0.0\nsamples = 24\nvalue = 0.609'),
#  Text(0.4194915254237288, 0.34615384615384615, 'squared_error = 0.0\nsamples = 3\nvalue = 0.605'),
#  Text(0.4279661016949153, 0.34615384615384615, 'squared_error = 0.0\nsamples = 21\nvalue = 0.61'),
#  Text(0.4449152542372881, 0.5769230769230769, 'x[1] <= 0.627\nsquared_error = 0.0\nsamples = 61\nvalue = 0.625'),
#  Text(0.4364406779661017, 0.5, 'x[1] <= 0.618\nsquared_error = 0.0\nsamples = 30\nvalue = 0.62'),
#  Text(0.4322033898305085, 0.4230769230769231, 'squared_error = 0.0\nsamples = 5\nvalue = 0.615'),
#  Text(0.4406779661016949, 0.4230769230769231, 'x[1] <= 0.623\nsquared_error = 0.0\nsamples = 25\nvalue = 0.621'),
#  Text(0.4364406779661017, 0.34615384615384615, 'x[0] <= 6.15\nsquared_error = 0.0\nsamples = 22\nvalue = 0.62'),
#  Text(0.4322033898305085, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 0.62'),
#  Text(0.4406779661016949, 0.2692307692307692, 'x[7] <= 0.996\nsquared_error = 0.0\nsamples = 21\nvalue = 0.62'),
#  Text(0.4364406779661017, 0.19230769230769232, 'squared_error = -0.0\nsamples = 8\nvalue = 0.62'),
#  Text(0.4449152542372881, 0.19230769230769232, 'x[10] <= 9.25\nsquared_error = 0.0\nsamples = 13\nvalue = 0.62'),
#  Text(0.4406779661016949, 0.11538461538461539, 'squared_error = 0.0\nsamples = 1\nvalue = 0.62'),
#  Text(0.4491525423728814, 0.11538461538461539, 'squared_error = 0.0\nsamples = 12\nvalue = 0.62'),
#  Text(0.4449152542372881, 0.34615384615384615, 'squared_error = -0.0\nsamples = 3\nvalue = 0.625'),
#  Text(0.4533898305084746, 0.5, 'x[1] <= 0.632\nsquared_error = 0.0\nsamples = 31\nvalue = 0.631'),
#  Text(0.4491525423728814, 0.4230769230769231, 'squared_error = -0.0\nsamples = 25\nvalue = 0.63'),
#  Text(0.4576271186440678, 0.4230769230769231, 'squared_error = -0.0\nsamples = 6\nvalue = 0.635'),
#  Text(0.5323093220338984, 0.7307692307692307, 'x[1] <= 0.697\nsquared_error = 0.001\nsamples = 201\nvalue = 0.687'),
#  Text(0.4957627118644068, 0.6538461538461539, 'x[1] <= 0.668\nsquared_error = 0.0\nsamples = 130\nvalue = 0.665'),
#  Text(0.4788135593220339, 0.5769230769230769, 'x[1] <= 0.652\nsquared_error = 0.0\nsamples = 71\nvalue = 0.65'),
#  Text(0.4703389830508475, 0.5, 'x[1] <= 0.642\nsquared_error = 0.0\nsamples = 44\nvalue = 0.644'),
#  Text(0.4661016949152542, 0.4230769230769231, 'squared_error = -0.0\nsamples = 20\nvalue = 0.64'),
#  Text(0.4745762711864407, 0.4230769230769231, 'x[1] <= 0.647\nsquared_error = 0.0\nsamples = 24\nvalue = 0.648'),
#  Text(0.4703389830508475, 0.34615384615384615, 'squared_error = -0.0\nsamples = 9\nvalue = 0.645'),
#  Text(0.4788135593220339, 0.34615384615384615, 'squared_error = -0.0\nsamples = 15\nvalue = 0.65'),
#  Text(0.4872881355932203, 0.5, 'x[1] <= 0.657\nsquared_error = 0.0\nsamples = 27\nvalue = 0.659'),
#  Text(0.4830508474576271, 0.4230769230769231, 'squared_error = -0.0\nsamples = 6\nvalue = 0.655'),
#  Text(0.4915254237288136, 0.4230769230769231, 'x[1] <= 0.663\nsquared_error = 0.0\nsamples = 21\nvalue = 0.66'),
#  Text(0.4872881355932203, 0.34615384615384615, 'squared_error = -0.0\nsamples = 19\nvalue = 0.66'),
#  Text(0.4957627118644068, 0.34615384615384615, 'x[3] <= 1.95\nsquared_error = 0.0\nsamples = 2\nvalue = 0.665'),
#  Text(0.4915254237288136, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 0.665'),
#  Text(0.5, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 0.665'),
#  Text(0.5127118644067796, 0.5769230769230769, 'x[1] <= 0.683\nsquared_error = 0.0\nsamples = 59\nvalue = 0.682'),
#  Text(0.5042372881355932, 0.5, 'x[1] <= 0.673\nsquared_error = 0.0\nsamples = 28\nvalue = 0.674'),
#  Text(0.5, 0.4230769230769231, 'squared_error = 0.0\nsamples = 17\nvalue = 0.67'),
#  Text(0.5084745762711864, 0.4230769230769231, 'x[1] <= 0.678\nsquared_error = 0.0\nsamples = 11\nvalue = 0.679'),
#  Text(0.5042372881355932, 0.34615384615384615, 'squared_error = 0.0\nsamples = 2\nvalue = 0.675'),
#  Text(0.5127118644067796, 0.34615384615384615, 'squared_error = 0.0\nsamples = 9\nvalue = 0.68'),
#  Text(0.5211864406779662, 0.5, 'x[1] <= 0.688\nsquared_error = 0.0\nsamples = 31\nvalue = 0.689'),
#  Text(0.5169491525423728, 0.4230769230769231, 'squared_error = 0.0\nsamples = 9\nvalue = 0.685'),
#  Text(0.5254237288135594, 0.4230769230769231, 'x[1] <= 0.692\nsquared_error = 0.0\nsamples = 22\nvalue = 0.691'),
#  Text(0.5211864406779662, 0.34615384615384615, 'squared_error = 0.0\nsamples = 17\nvalue = 0.69'),
#  Text(0.5296610169491526, 0.34615384615384615, 'x[8] <= 3.23\nsquared_error = 0.0\nsamples = 5\nvalue = 0.695'),
#  Text(0.5254237288135594, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 0.695'),
#  Text(0.5338983050847458, 0.2692307692307692, 'squared_error = 0.0\nsamples = 4\nvalue = 0.695'),
#  Text(0.5688559322033898, 0.6538461538461539, 'x[1] <= 0.728\nsquared_error = 0.0\nsamples = 71\nvalue = 0.728'),
#  Text(0.5466101694915254, 0.5769230769230769, 'x[1] <= 0.712\nsquared_error = 0.0\nsamples = 36\nvalue = 0.713'),
#  Text(0.538135593220339, 0.5, 'x[1] <= 0.702\nsquared_error = 0.0\nsamples = 14\nvalue = 0.704'),
#  Text(0.5338983050847458, 0.4230769230769231, 'squared_error = -0.0\nsamples = 7\nvalue = 0.7'),
#  Text(0.5423728813559322, 0.4230769230769231, 'x[2] <= 0.025\nsquared_error = 0.0\nsamples = 7\nvalue = 0.707'),
#  Text(0.538135593220339, 0.34615384615384615, 'squared_error = 0.0\nsamples = 3\nvalue = 0.71'),
#  Text(0.5466101694915254, 0.34615384615384615, 'squared_error = 0.0\nsamples = 4\nvalue = 0.705'),
#  Text(0.5550847457627118, 0.5, 'x[1] <= 0.718\nsquared_error = 0.0\nsamples = 22\nvalue = 0.719'),
#  Text(0.5508474576271186, 0.4230769230769231, 'squared_error = -0.0\nsamples = 10\nvalue = 0.715'),
#  Text(0.559322033898305, 0.4230769230769231, 'x[1] <= 0.723\nsquared_error = 0.0\nsamples = 12\nvalue = 0.723'),
#  Text(0.5550847457627118, 0.34615384615384615, 'squared_error = 0.0\nsamples = 5\nvalue = 0.72'),
#  Text(0.5635593220338984, 0.34615384615384615, 'squared_error = 0.0\nsamples = 7\nvalue = 0.725'),
#  Text(0.5911016949152542, 0.5769230769230769, 'x[1] <= 0.743\nsquared_error = 0.0\nsamples = 35\nvalue = 0.743'),
#  Text(0.5805084745762712, 0.5, 'x[1] <= 0.738\nsquared_error = 0.0\nsamples = 20\nvalue = 0.737'),
#  Text(0.576271186440678, 0.4230769230769231, 'x[1] <= 0.733\nsquared_error = 0.0\nsamples = 10\nvalue = 0.734'),
#  Text(0.5720338983050848, 0.34615384615384615, 'squared_error = 0.0\nsamples = 3\nvalue = 0.73'),
#  Text(0.5805084745762712, 0.34615384615384615, 'squared_error = -0.0\nsamples = 7\nvalue = 0.735'),
#  Text(0.5847457627118644, 0.4230769230769231, 'squared_error = -0.0\nsamples = 10\nvalue = 0.74'),
#  Text(0.6016949152542372, 0.5, 'x[1] <= 0.752\nsquared_error = 0.0\nsamples = 15\nvalue = 0.751'),
#  Text(0.5932203389830508, 0.4230769230769231, 'x[1] <= 0.748\nsquared_error = 0.0\nsamples = 10\nvalue = 0.748'),
#  Text(0.5889830508474576, 0.34615384615384615, 'squared_error = 0.0\nsamples = 5\nvalue = 0.745'),
#  Text(0.597457627118644, 0.34615384615384615, 'squared_error = -0.0\nsamples = 5\nvalue = 0.75'),
#  Text(0.6101694915254238, 0.4230769230769231, 'x[1] <= 0.757\nsquared_error = 0.0\nsamples = 5\nvalue = 0.758'),
#  Text(0.6059322033898306, 0.34615384615384615, 'squared_error = 0.0\nsamples = 2\nvalue = 0.755'),
#  Text(0.614406779661017, 0.34615384615384615, 'squared_error = -0.0\nsamples = 3\nvalue = 0.76'),
#  Text(0.856594279661017, 0.8076923076923077, 'x[1] <= 0.955\nsquared_error = 0.017\nsamples = 119\nvalue = 0.899'),
#  Text(0.7526483050847458, 0.7307692307692307, 'x[1] <= 0.848\nsquared_error = 0.002\nsamples = 87\nvalue = 0.837'),
#  Text(0.6864406779661016, 0.6538461538461539, 'x[1] <= 0.805\nsquared_error = 0.001\nsamples = 53\nvalue = 0.804'),
#  Text(0.652542372881356, 0.5769230769230769, 'x[1] <= 0.782\nsquared_error = 0.0\nsamples = 29\nvalue = 0.782'),
#  Text(0.635593220338983, 0.5, 'x[1] <= 0.772\nsquared_error = 0.0\nsamples = 15\nvalue = 0.776'),
#  Text(0.6271186440677966, 0.4230769230769231, 'x[5] <= 34.5\nsquared_error = 0.0\nsamples = 5\nvalue = 0.769'),
#  Text(0.6228813559322034, 0.34615384615384615, 'squared_error = 0.0\nsamples = 4\nvalue = 0.77'),
#  Text(0.6313559322033898, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 0.765'),
#  Text(0.6440677966101694, 0.4230769230769231, 'x[1] <= 0.777\nsquared_error = 0.0\nsamples = 10\nvalue = 0.779'),
#  Text(0.6398305084745762, 0.34615384615384615, 'squared_error = 0.0\nsamples = 2\nvalue = 0.775'),
#  Text(0.6483050847457628, 0.34615384615384615, 'squared_error = -0.0\nsamples = 8\nvalue = 0.78'),
#  Text(0.6694915254237288, 0.5, 'x[1] <= 0.793\nsquared_error = 0.0\nsamples = 14\nvalue = 0.789'),
#  Text(0.6610169491525424, 0.4230769230769231, 'x[7] <= 0.996\nsquared_error = 0.0\nsamples = 10\nvalue = 0.786'),
#  Text(0.6567796610169492, 0.34615384615384615, 'squared_error = 0.0\nsamples = 2\nvalue = 0.79'),
#  Text(0.6652542372881356, 0.34615384615384615, 'squared_error = 0.0\nsamples = 8\nvalue = 0.785'),
#  Text(0.6779661016949152, 0.4230769230769231, 'x[2] <= 0.055\nsquared_error = 0.0\nsamples = 4\nvalue = 0.798'),
#  Text(0.673728813559322, 0.34615384615384615, 'squared_error = 0.0\nsamples = 2\nvalue = 0.795'),
#  Text(0.6822033898305084, 0.34615384615384615, 'squared_error = -0.0\nsamples = 2\nvalue = 0.8'),
#  Text(0.7203389830508474, 0.5769230769230769, 'x[1] <= 0.827\nsquared_error = 0.0\nsamples = 24\nvalue = 0.83'),
#  Text(0.7033898305084746, 0.5, 'x[1] <= 0.817\nsquared_error = 0.0\nsamples = 8\nvalue = 0.818'),
#  Text(0.6949152542372882, 0.4230769230769231, 'x[4] <= 0.071\nsquared_error = 0.0\nsamples = 4\nvalue = 0.814'),
#  Text(0.690677966101695, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 0.81'),
#  Text(0.6991525423728814, 0.34615384615384615, 'squared_error = 0.0\nsamples = 3\nvalue = 0.815'),
#  Text(0.711864406779661, 0.4230769230769231, 'x[5] <= 13.0\nsquared_error = 0.0\nsamples = 4\nvalue = 0.821'),
#  Text(0.7076271186440678, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 0.825'),
#  Text(0.7161016949152542, 0.34615384615384615, 'squared_error = -0.0\nsamples = 3\nvalue = 0.82'),
#  Text(0.7372881355932204, 0.5, 'x[1] <= 0.837\nsquared_error = 0.0\nsamples = 16\nvalue = 0.837'),
#  Text(0.7288135593220338, 0.4230769230769231, 'x[1] <= 0.832\nsquared_error = 0.0\nsamples = 8\nvalue = 0.832'),
#  Text(0.7245762711864406, 0.34615384615384615, 'squared_error = 0.0\nsamples = 4\nvalue = 0.83'),
#  Text(0.7330508474576272, 0.34615384615384615, 'squared_error = -0.0\nsamples = 4\nvalue = 0.835'),
#  Text(0.7457627118644068, 0.4230769230769231, 'x[1] <= 0.843\nsquared_error = 0.0\nsamples = 8\nvalue = 0.841'),
#  Text(0.7415254237288136, 0.34615384615384615, 'squared_error = -0.0\nsamples = 7\nvalue = 0.84'),
#  Text(0.75, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 0.845'),
#  Text(0.8188559322033898, 0.6538461538461539, 'x[1] <= 0.892\nsquared_error = 0.001\nsamples = 34\nvalue = 0.888'),
#  Text(0.788135593220339, 0.5769230769230769, 'x[1] <= 0.868\nsquared_error = 0.0\nsamples = 20\nvalue = 0.87'),
#  Text(0.7711864406779662, 0.5, 'x[1] <= 0.858\nsquared_error = 0.0\nsamples = 8\nvalue = 0.856'),
#  Text(0.7627118644067796, 0.4230769230769231, 'x[6] <= 46.0\nsquared_error = 0.0\nsamples = 5\nvalue = 0.853'),
#  Text(0.7584745762711864, 0.34615384615384615, 'squared_error = 0.0\nsamples = 3\nvalue = 0.855'),
#  Text(0.7669491525423728, 0.34615384615384615, 'squared_error = -0.0\nsamples = 2\nvalue = 0.85'),
#  Text(0.7796610169491526, 0.4230769230769231, 'x[1] <= 0.863\nsquared_error = 0.0\nsamples = 3\nvalue = 0.862'),
#  Text(0.7754237288135594, 0.34615384615384615, 'squared_error = 0.0\nsamples = 2\nvalue = 0.86'),
#  Text(0.7838983050847458, 0.34615384615384615, 'squared_error = -0.0\nsamples = 1\nvalue = 0.865'),
#  Text(0.8050847457627118, 0.5, 'x[1] <= 0.877\nsquared_error = 0.0\nsamples = 12\nvalue = 0.878'),
#  Text(0.7966101694915254, 0.4230769230769231, 'x[1] <= 0.873\nsquared_error = 0.0\nsamples = 5\nvalue = 0.872'),
#  Text(0.7923728813559322, 0.34615384615384615, 'squared_error = -0.0\nsamples = 3\nvalue = 0.87'),
#  Text(0.8008474576271186, 0.34615384615384615, 'squared_error = -0.0\nsamples = 2\nvalue = 0.875'),
#  Text(0.8135593220338984, 0.4230769230769231, 'x[1] <= 0.882\nsquared_error = 0.0\nsamples = 7\nvalue = 0.883'),
#  Text(0.809322033898305, 0.34615384615384615, 'squared_error = -0.0\nsamples = 4\nvalue = 0.88'),
#  Text(0.8177966101694916, 0.34615384615384615, 'x[8] <= 3.115\nsquared_error = 0.0\nsamples = 3\nvalue = 0.887'),
#  Text(0.8135593220338984, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 0.89'),
#  Text(0.8220338983050848, 0.2692307692307692, 'squared_error = 0.0\nsamples = 2\nvalue = 0.885'),
#  Text(0.8495762711864406, 0.5769230769230769, 'x[1] <= 0.928\nsquared_error = 0.0\nsamples = 14\nvalue = 0.915'),
#  Text(0.8389830508474576, 0.5, 'x[1] <= 0.905\nsquared_error = 0.0\nsamples = 11\nvalue = 0.908'),
#  Text(0.8305084745762712, 0.4230769230769231, 'x[1] <= 0.897\nsquared_error = 0.0\nsamples = 4\nvalue = 0.899'),
#  Text(0.826271186440678, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 0.895'),
#  Text(0.8347457627118644, 0.34615384615384615, 'squared_error = 0.0\nsamples = 3\nvalue = 0.9'),
#  Text(0.847457627118644, 0.4230769230769231, 'x[1] <= 0.913\nsquared_error = 0.0\nsamples = 7\nvalue = 0.914'),
#  Text(0.8432203389830508, 0.34615384615384615, 'squared_error = 0.0\nsamples = 3\nvalue = 0.91'),
#  Text(0.8516949152542372, 0.34615384615384615, 'x[0] <= 8.7\nsquared_error = 0.0\nsamples = 4\nvalue = 0.916'),
#  Text(0.847457627118644, 0.2692307692307692, 'squared_error = 0.0\nsamples = 3\nvalue = 0.915'),
#  Text(0.8559322033898306, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 0.92'),
#  Text(0.8601694915254238, 0.5, 'x[2] <= 0.125\nsquared_error = 0.0\nsamples = 3\nvalue = 0.94'),
#  Text(0.8559322033898306, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 0.95'),
#  Text(0.864406779661017, 0.4230769230769231, 'squared_error = 0.0\nsamples = 2\nvalue = 0.935'),
#  Text(0.9605402542372882, 0.7307692307692307, 'x[1] <= 1.155\nsquared_error = 0.018\nsamples = 32\nvalue = 1.069'),
#  Text(0.9295550847457628, 0.6538461538461539, 'x[1] <= 1.055\nsquared_error = 0.002\nsamples = 26\nvalue = 1.014'),
#  Text(0.9014830508474576, 0.5769230769230769, 'x[1] <= 0.99\nsquared_error = 0.001\nsamples = 22\nvalue = 0.998'),
#  Text(0.8813559322033898, 0.5, 'x[1] <= 0.97\nsquared_error = 0.0\nsamples = 9\nvalue = 0.97'),
#  Text(0.8728813559322034, 0.4230769230769231, 'x[10] <= 10.55\nsquared_error = 0.0\nsamples = 5\nvalue = 0.963'),
#  Text(0.8686440677966102, 0.34615384615384615, 'squared_error = 0.0\nsamples = 3\nvalue = 0.965'),
#  Text(0.8771186440677966, 0.34615384615384615, 'squared_error = 0.0\nsamples = 2\nvalue = 0.96'),
#  Text(0.8898305084745762, 0.4230769230769231, 'x[4] <= 0.082\nsquared_error = 0.0\nsamples = 4\nvalue = 0.979'),
#  Text(0.885593220338983, 0.34615384615384615, 'squared_error = 0.0\nsamples = 3\nvalue = 0.98'),
#  Text(0.8940677966101694, 0.34615384615384615, 'squared_error = -0.0\nsamples = 1\nvalue = 0.975'),
#  Text(0.9216101694915254, 0.5, 'x[1] <= 1.015\nsquared_error = 0.0\nsamples = 13\nvalue = 1.018'),
#  Text(0.9067796610169492, 0.4230769230769231, 'x[5] <= 9.0\nsquared_error = 0.0\nsamples = 5\nvalue = 1.003'),
#  Text(0.902542372881356, 0.34615384615384615, 'squared_error = 0.0\nsamples = 3\nvalue = 1.0'),
#  Text(0.9110169491525424, 0.34615384615384615, 'x[4] <= 0.07\nsquared_error = 0.0\nsamples = 2\nvalue = 1.007'),
#  Text(0.9067796610169492, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 1.01'),
#  Text(0.9152542372881356, 0.2692307692307692, 'squared_error = 0.0\nsamples = 1\nvalue = 1.005'),
#  Text(0.9364406779661016, 0.4230769230769231, 'x[1] <= 1.03\nsquared_error = 0.0\nsamples = 8\nvalue = 1.028'),
#  Text(0.9279661016949152, 0.34615384615384615, 'x[1] <= 1.022\nsquared_error = 0.0\nsamples = 5\nvalue = 1.021'),
#  Text(0.923728813559322, 0.2692307692307692, 'squared_error = 0.0\nsamples = 4\nvalue = 1.02'),
#  Text(0.9322033898305084, 0.2692307692307692, 'squared_error = -0.0\nsamples = 1\nvalue = 1.025'),
#  Text(0.9449152542372882, 0.34615384615384615, 'x[0] <= 8.15\nsquared_error = 0.0\nsamples = 3\nvalue = 1.038'),
#  Text(0.940677966101695, 0.2692307692307692, 'squared_error = 0.0\nsamples = 2\nvalue = 1.04'),
#  Text(0.9491525423728814, 0.2692307692307692, 'squared_error = -0.0\nsamples = 1\nvalue = 1.035'),
#  Text(0.9576271186440678, 0.5769230769230769, 'x[1] <= 1.103\nsquared_error = 0.001\nsamples = 4\nvalue = 1.101'),
#  Text(0.9491525423728814, 0.5, 'x[6] <= 60.0\nsquared_error = 0.0\nsamples = 2\nvalue = 1.08'),
#  Text(0.9449152542372882, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 1.09'),
#  Text(0.9533898305084746, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 1.07'),
#  Text(0.9661016949152542, 0.5, 'x[1] <= 1.123\nsquared_error = 0.0\nsamples = 2\nvalue = 1.122'),
#  Text(0.961864406779661, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 1.115'),
#  Text(0.9703389830508474, 0.4230769230769231, 'squared_error = -0.0\nsamples = 1\nvalue = 1.13'),
#  Text(0.9915254237288136, 0.6538461538461539, 'x[1] <= 1.455\nsquared_error = 0.019\nsamples = 6\nvalue = 1.307'),
#  Text(0.9872881355932204, 0.5769230769230769, 'x[10] <= 10.8\nsquared_error = 0.004\nsamples = 5\nvalue = 1.253'),
#  Text(0.9830508474576272, 0.5, 'x[8] <= 3.245\nsquared_error = 0.001\nsamples = 3\nvalue = 1.202'),
#  Text(0.9788135593220338, 0.4230769230769231, 'squared_error = 0.0\nsamples = 1\nvalue = 1.24'),
#  Text(0.9872881355932204, 0.4230769230769231, 'x[3] <= 3.075\nsquared_error = 0.0\nsamples = 2\nvalue = 1.182'),
#  Text(0.9830508474576272, 0.34615384615384615, 'squared_error = 0.0\nsamples = 1\nvalue = 1.18'),
#  Text(0.9915254237288136, 0.34615384615384615, 'squared_error = -0.0\nsamples = 1\nvalue = 1.185'),
#  Text(0.9915254237288136, 0.5, 'squared_error = 0.0\nsamples = 2\nvalue = 1.33'),
#  Text(0.9957627118644068, 0.5769230769230769, 'squared_error = 0.0\nsamples = 1\nvalue = 1.58')]

# %%
y_pred = regressor.predict(X_test)
y_pred
# Out:
# array([0.47 , 0.825, 0.29 , 0.645, 0.45 , 0.64 , 0.715, 0.36 , 0.95 ,
#        0.735, 0.52 , 0.68 , 0.5  , 1.04 , 0.58 , 0.31 , 0.28 , 0.4  ,
#        0.6  , 0.59 , 0.66 , 0.53 , 0.51 , 0.33 , 0.365, 0.64 , 0.58 ,
#        0.34 , 0.38 , 0.47 , 0.24 , 0.42 , 0.56 , 0.68 , 0.84 , 0.33 ,
#        0.63 , 0.54 , 0.4  , 0.55 , 0.46 , 0.48 , 0.4  , 0.49 , 0.41 ,
#        0.815, 0.57 , 0.36 , 0.52 , 0.28 , 0.45 , 0.32 , 0.41 , 0.47 ,
#        0.31 , 0.6  , 0.53 , 0.63 , 0.36 , 0.58 , 0.67 , 0.41 , 0.44 ,
#        0.36 , 0.66 , 0.44 , 0.695, 0.645, 0.34 , 0.53 , 0.77 , 0.32 ,
#        0.73 , 0.51 , 0.48 , 0.49 , 0.57 , 0.34 , 0.5  , 0.39 , 0.48 ,
#        0.39 , 0.44 , 0.29 , 0.64 , 0.67 , 0.39 , 0.655, 0.52 , 0.73 ,
#        0.52 , 0.61 , 0.58 , 0.58 , 0.27 , 0.77 , 0.27 , 0.5  , 0.55 ,
#        0.36 , 0.32 , 0.27 , 0.635, 0.16 , 0.52 , 0.67 , 0.52 , 0.59 ,
#        0.56 , 0.715, 0.61 , 0.77 , 0.37 , 0.725, 0.77 , 0.45 , 0.53 ,
#        0.4  , 0.76 , 0.51 , 0.58 , 0.5  , 0.46 , 0.5  , 0.66 , 0.37 ,
#        0.43 , 0.41 , 0.2  , 0.39 , 0.35 , 0.69 , 0.5  , 0.58 , 0.18 ,
#        0.47 , 0.415, 0.635, 0.31 , 0.5  , 0.75 , 0.7  , 0.57 , 0.65 ,
#        0.68 , 0.39 , 0.37 , 0.26 , 0.47 , 0.43 , 0.35 , 0.28 , 0.59 ,
#        0.66 , 0.66 , 0.685, 0.58 , 0.645, 0.5  , 0.4  , 0.51 , 0.49 ,
#        0.35 , 0.59 , 0.6  , 0.87 , 0.51 , 0.31 , 0.59 , 0.5  , 0.38 ,
#        0.5  , 0.62 , 0.3  , 0.795, 0.34 , 0.28 , 0.41 , 0.66 , 0.665,
#        0.57 , 0.36 , 0.55 , 0.27 , 0.29 , 0.67 , 0.4  , 0.635, 0.69 ,
#        0.32 , 0.5  , 0.54 , 0.49 , 0.42 , 0.59 , 0.56 , 0.52 , 0.825,
#        0.64 , 0.62 , 0.42 , 0.49 , 0.63 , 0.675, 0.67 , 0.6  , 0.74 ,
#        0.365, 0.31 , 0.38 , 0.37 , 0.21 , 0.56 , 0.53 , 0.695, 0.6  ,
#        0.36 , 0.31 , 0.57 , 0.63 , 0.7  , 0.41 , 0.4  , 0.4  , 0.59 ,
#        0.35 , 0.4  , 0.47 , 0.61 , 0.5  , 0.66 , 0.64 , 0.915, 0.5  ,
#        0.38 , 0.59 , 0.39 , 0.31 , 0.36 , 0.52 , 0.61 , 0.77 , 0.69 ,
#        0.705, 0.4  , 0.73 , 0.33 , 0.69 , 0.78 , 0.3  , 0.755, 0.7  ,
#        0.775, 0.78 , 0.5  , 0.5  , 0.6  , 0.89 , 0.61 , 0.615, 0.69 ,
#        0.34 , 0.55 , 0.4  , 0.685, 0.885, 0.705, 0.64 , 0.5  , 0.18 ,
#        0.31 , 0.43 , 0.42 , 0.52 , 0.5  , 0.67 , 0.24 , 0.58 , 0.22 ,
#        0.53 , 0.59 , 0.29 , 0.43 , 0.45 , 0.26 , 0.59 , 0.34 , 0.56 ,
#        0.34 , 0.41 , 0.43 , 0.96 , 0.22 , 0.43 , 0.76 , 0.69 , 0.36 ,
#        0.49 , 0.725, 0.46 , 0.64 , 0.885, 0.53 , 0.29 , 0.34 , 0.61 ,
#        0.775, 0.795, 0.33 , 0.54 , 0.365, 0.51 , 0.46 , 0.5  , 0.88 ,
#        0.27 , 0.39 , 0.34 , 0.77 , 0.32 ])

# %%
df = pd.DataFrame({'Actual': y_test, 'Predicted': y_pred})
df
# Out:
#      Actual  Predicted
# 0     0.470      0.470
# 1     0.820      0.825
# 2     0.290      0.290
# 3     0.645      0.645
# 4     0.450      0.450
# ..      ...        ...
# 315   0.270      0.270
# 316   0.390      0.390
# 317   0.340      0.340
# 318   0.765      0.770
# 319   0.320      0.320
#
# [320 rows x 2 columns]

# %%
from sklearn import metrics

print('Mean Squared Error: ', metrics.mean_squared_error(y_test, y_pred))
print('Mean Absolute Error: ', metrics.mean_absolute_error(y_test, y_pred))
# Out:
# Mean Squared Error:  1.7968750000000068e-06
# Mean Absolute Error:  0.00029687500000009134
